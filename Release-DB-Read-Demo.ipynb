# %% [markdown]
# ## Merge database tables into a flat dataframe

# %%
import sqlite3
import pandas as pd

pd.set_option("display.max_colwidth", 60)
pd.set_option("display.max_rows", 100)

# %%
RELEASE_DB_NAME = "release_db.sqlite"
conn = sqlite3.connect(RELEASE_DB_NAME)
conn

# %% [markdown]
# ### Read in the tables

# %%
# we'll merge everything into this dataframe
df = pd.read_sql_query("SELECT * FROM policy_snapshots", conn)

sites_df = pd.read_sql_query("SELECT * FROM sites", conn)
policy_texts_df = pd.read_sql_query("SELECT * FROM policy_texts", conn)
alexa_ranks_df = pd.read_sql_query("SELECT * FROM alexa_ranks", conn)

# %%
# Left join with policy text table
df = pd.merge(df, policy_texts_df, how="left", left_on="policy_text_id", right_on="id")

# Left join with sites table
df = pd.merge(df, sites_df, how="left", left_on="site_id", right_on="id")

# Left join with alexa ranks table
df = pd.merge(df, alexa_ranks_df, how="left", on=['site_id', 'year', 'phase'])

# %%
df_simplified = df[['id_x', 'analysis_subcorpus', 'domain', 'rank', 'year', 'phase','categories', 'flesch_kincaid','flesch_ease', 'smog', 'length', 'cross_domain_homepage_redir']]
df_simplified = df_simplified.loc[df_simplified['analysis_subcorpus'] == 1]

df_simplified['Year Phase'] = df['year'].astype(str) + df['phase']
df_simplified['Organisation'] = df_simplified['domain'].str.split('.').str[0]
df_simplified['rank (bin)'] = pd.cut(df_simplified['rank'], [0, 1000, 10000, 100000, 1000000])

df_simplified.head(20)
# Out:
#     id_x  analysis_subcorpus        domain      rank  year phase  \
# 0      1                   1  docusign.com       NaN  2003     B
# 1      2                   1  docusign.com       NaN  2004     B
# 2      3                   1  docusign.com       NaN  2006     B
# 3      4                   1  docusign.com       NaN  2006     A
# 4      5                   1  docusign.com       NaN  2004     A
# 5      6                   1  docusign.com       NaN  2005     A
# 6      7                   1  docusign.com       NaN  2008     A
# 7      8                   1  docusign.com       NaN  2007     A
# 8      9                   1  docusign.com       NaN  2007     B
# 9     10                   1  docusign.com       NaN  2008     B
# 10    11                   1  docusign.com   74546.0  2009     B
# 11    12                   1  docusign.com  104574.0  2009     A
# 12    13                   1  docusign.com   24961.0  2011     A
# 13    14                   1  docusign.com   22010.0  2011     B
# 14    15                   1  docusign.com   41297.0  2010     A
# 15    16                   1  docusign.com   18282.0  2012     B
# 16    17                   1  docusign.com   18011.0  2012     A
# 17    18                   1  docusign.com   17393.0  2013     A
# 18    19                   1  docusign.com   10504.0  2013     B
# 19    20                   1  docusign.com   13280.0  2014     A
#
#                   categories  flesch_kincaid     flesch_ease       smog  \
# 0   business;informationtech       14.938384       difficult  18.351184
# 1   business;informationtech       13.762202       difficult  18.171460
# 2   business;informationtech       13.640407       difficult  18.062587
# 3   business;informationtech       13.640407       difficult  18.062587
# 4   business;informationtech       13.762202       difficult  18.171460
# 5   business;informationtech       13.651666       difficult  18.062587
# 6   business;informationtech       13.660300       difficult  18.098966
# 7   business;informationtech       13.640407       difficult  18.062587
# 8   business;informationtech       13.655114       difficult  18.062587
# 9   business;informationtech       13.660300       difficult  18.098966
# 10  business;informationtech       14.005176       difficult  17.618919
# 11  business;informationtech       14.005176       difficult  17.618919
# 12  business;informationtech       15.140621  very_confusing  18.634410
# 13  business;informationtech       15.098912       difficult  19.049804
# 14  business;informationtech       14.005176       difficult  17.618919
# 15  business;informationtech       13.595953       difficult  17.842426
# 16  business;informationtech       13.595953       difficult  17.842426
# 17  business;informationtech       13.595953       difficult  17.842426
# 18  business;informationtech       13.595953       difficult  17.842426
# 19  business;informationtech       13.392650       difficult  16.322122
#
#     length  cross_domain_homepage_redir Year Phase Organisation  \
# 0    14137                            0      2003B     docusign
# 1    14366                            0      2004B     docusign
# 2    14363                            0      2006B     docusign
# 3    14363                            0      2006A     docusign
# 4    14366                            0      2004A     docusign
# 5    14394                            0      2005A     docusign
# 6    14396                            0      2008A     docusign
# 7    14363                            0      2007A     docusign
# 8    14391                            0      2007B     docusign
# 9    14396                            0      2008B     docusign
# 10   16768                            0      2009B     docusign
# 11   16768                            0      2009A     docusign
# 12   16798                            0      2011A     docusign
# 13   19022                            0      2011B     docusign
# 14   16768                            0      2010A     docusign
# 15   24985                            0      2012B     docusign
# 16   24965                            0      2012A     docusign
# 17   24985                            0      2013A     docusign
# 18   24985                            0      2013B     docusign
# 19   25657                            0      2014A     docusign
#
#                rank (bin)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10    (10000.0, 100000.0]
# 11  (100000.0, 1000000.0]
# 12    (10000.0, 100000.0]
# 13    (10000.0, 100000.0]
# 14    (10000.0, 100000.0]
# 15    (10000.0, 100000.0]
# 16    (10000.0, 100000.0]
# 17    (10000.0, 100000.0]
# 18    (10000.0, 100000.0]
# 19    (10000.0, 100000.0]

# %%
df_simplified.to_csv('simplified_policy_data.csv')
